# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
japanize_matplotlib.japanize()

# %%
data = pd.read_csv("C:\\Users\\ohrtt\\Documents\\GitHub\\c3_2024\\data_analysis\\select_target\\data.csv")
data
# Out:
#       rowid      toi  toipfx        tid    ctoi_alias  pl_pnum tfopwg_disp  \
# 0         1  1000.01    1000   50365310  5.036531e+07        1          FP
# 1         2  1001.01    1001   88863718  8.886372e+07        1          PC
# 2         3  1002.01    1002  124709665  1.247097e+08        1          FP
# 3         4  1003.01    1003  106997505  1.069975e+08        1          FP
# 4         5  1004.01    1004  238597883  2.385979e+08        1          FP
# ...     ...      ...     ...        ...           ...      ...         ...
# 7231   7232   995.01     995  317951248  3.179512e+08        1          FP
# 7232   7233   996.01     996  142918609  1.429186e+08        1          FP
# 7233   7234   997.01     997  341729521  3.417295e+08        1          FP
# 7234   7235   998.01     998   54390047  5.439005e+07        1          FP
# 7235   7236   999.01     999  341186896  3.411869e+08        1          FP
#
# ...

# %%
# 観測可能領域に位置する天体のみ
data_sel = data[(data['ra'] > 315) & (data['ra'] < 360) & (data['dec'] > 15) & (data['dec'] < 45)]

# %%
data_sel
# Out:
#       rowid      toi  toipfx        tid    ctoi_alias  pl_pnum tfopwg_disp  \
# 329     330  1275.01    1275   13499636  1.349964e+07        1          FA
# 333     334  1278.01    1278  163539739  1.635397e+08        1          CP
# 339     340  1283.01    1283  266593143  2.665931e+08        1          KP
# 374     375  1314.01    1314  136848581  1.368486e+08        1          FP
# 377     378  1317.01    1317  165523947  1.655239e+08        1          FP
# ...     ...      ...     ...        ...           ...      ...         ...
# 5982   5983  6238.01    6238  125489084  1.254891e+08        1          PC
# 5997   5998  6250.01    6250  455737331  4.557373e+08        1          PC
# 6002   6003  6255.01    6255  261135533  2.611355e+08        1          PC
# 6855   6856  7011.01    7011  167631701  1.676317e+08        1          PC
# 6867   6868  7022.01    7022  125366299  1.253663e+08        1          PC
#
# ...

# %%
# 100 pc以内, transit depth 1%以上の天体のみ抽出
data_sel2 = data_sel[(data_sel['st_dist']<100) & (data_sel['pl_trandep']>10000)]

# %%
data_sel2
save = data_sel2.to_csv("C:\\Users\\ohrtt\\Documents\\GitHub\\c3_2024\\data_analysis\\select_target\\data_sel2.csv")
# Out:
# c:\Users\ohrtt\Documents\GitHub\c3_2024\.venv\Lib\site-packages\pandas\core\indexes\base.py:7834: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
